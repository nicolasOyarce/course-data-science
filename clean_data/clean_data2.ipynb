# %% [markdown]
# # Extract Data

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_netflix = pd.read_csv('netflix_titles.csv')

# %%
df_netflix
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
# extract data the column "duration" with method split and extract
df_movie = df_netflix[df_netflix['type']=='Movie']
# Out:
# 0        90 min
# 6        91 min
# 7       125 min
# 9       104 min
# 12      127 min
#          ...
# 8801     96 min
# 8802    158 min
# 8804     88 min
# 8805     88 min
# 8806    111 min
# Name: duration, Length: 6131, dtype: object

# %%
# split
df_movie['minute'] = df_movie['duration'].str.split(expand=True)[0].astype(int)
# Out:
# /tmp/ipykernel_31164/1237029123.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_movie['minute'] = df_movie['duration'].str.split(expand=True)[0].astype(int)

# %%
df_movie
# Out:
#      show_id   type                             title  \
# 0         s1  Movie              Dick Johnson Is Dead
# 6         s7  Movie  My Little Pony: A New Generation
# 7         s8  Movie                           Sankofa
# 9        s10  Movie                      The Starling
# 12       s13  Movie                      Je Suis Karl
# ...      ...    ...                               ...
# 8801   s8802  Movie                           Zinzana
# 8802   s8803  Movie                            Zodiac
# 8804   s8805  Movie                        Zombieland
# 8805   s8806  Movie                              Zoom
# 8806   s8807  Movie                            Zubaan
#
#                            director  \
# 0                   Kirsten Johnson
# 6     Robert Cullen, José Luis Ucha
# 7                      Haile Gerima
# 9                    Theodore Melfi
# 12              Christian Schwochow
# ...                             ...
# 8801                Majid Al Ansari
# ...

# %%
df_movie.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# minute           int64
# dtype: object

# %%
#df_netflix['date_added'].str.split(pat='\d{4}', expand=True)
df_netflix['date_added'].str.extract('(\d{4})')
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# <>:2: SyntaxWarning: invalid escape sequence '\d'
# /tmp/ipykernel_31164/4192811659.py:2: SyntaxWarning: invalid escape sequence '\d'
#   df_netflix['date_added'].str.extract('(\d{4})')
#          0
# 0     2021
# 1     2021
# 2     2021
# 3     2021
# 4     2021
# ...    ...
# 8802  2019
# 8803  2019
# 8804  2019
# 8805  2020
# 8806  2019
#
# [8807 rows x 1 columns]

# %% [markdown]
# ## Atypical Values

# %%
# histograma
df_movie['minute'].plot(kind='hist', bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
# obtain range 
df_movie['minute'].value_counts(bins=10).sort_index()
# Out:
# (-0.313, 31.2]     135
# (31.2, 62.4]       410
# (62.4, 93.6]      1867
# (93.6, 124.8]     2772
# (124.8, 156.0]     766
# (156.0, 187.2]     150
# (187.2, 218.4]      22
# (218.4, 249.6]       6
# (249.6, 280.8]       2
# (280.8, 312.0]       1
# Name: count, dtype: int64

# %%
# manage atypical values
df_movie[~((df_movie['minute']>=31.2) & (df_movie['minute']<=218))]
# Out:
#      show_id   type                                              title  \
# 45       s46  Movie                             My Heroes Were Cowboys
# 71       s72  Movie                        A StoryBots Space Adventure
# 166     s167  Movie                        Once Upon a Time in America
# 694     s695  Movie                                              Aziza
# 695     s696  Movie                                     Besieged Bread
# ...      ...    ...                                                ...
# 7788   s7789  Movie  Power Rangers: Megaforce: The Robo Knight Befo...
# 7848   s7849  Movie                                            Refugee
# 7891   s7892  Movie                                  Room on the Broom
# 7932   s7933  Movie                                             Sangam
# 8205   s8206  Movie                               The Battle of Midway
#
#                              director  \
# 45                        Tyler Greco
# ...

# %%
# bloxplot
df_movie['minute'].plot(kind='box', vert=False, color='green', figsize=(10,5))
# Out:
# <Axes: >

# %%
# IQR = Q3-Q1 
min_bloxplot = 87 - 1.5*(114 - 87) #Q1 - 1.5*IQR 
max_bloxplot = 114 + 1.5*(114 - 87) #Q3 + 1.5*IQR

#df_movie['minute'].describe()
print(min_bloxplot)
print(max_bloxplot)
# Out:
# 46.5
# 154.5

# %%
df_movie[~((df_movie['minute']>=46.5) & (df_movie['minute']<=154.5))]
# Out:
#      show_id   type                            title         director  \
# 22       s23  Movie                  Avvai Shanmughi   K.S. Ravikumar
# 24       s25  Movie                            Jeans       S. Shankar
# 45       s46  Movie           My Heroes Were Cowboys      Tyler Greco
# 71       s72  Movie      A StoryBots Space Adventure  David A. Vargas
# 73       s74  Movie                     King of Boys     Kemi Adetiba
# ...      ...    ...                              ...              ...
# 8763   s8764  Movie  WWII: Report from the Aleutians      John Huston
# 8764   s8765  Movie                       Wyatt Earp  Lawrence Kasdan
# 8770   s8771  Movie                          Yaadein     Subhash Ghai
# 8788   s8789  Movie                     You Carry Me       Ivona Juka
# 8802   s8803  Movie                           Zodiac    David Fincher
#
#                                                    cast  \
# 22    Kamal Hassan, Meena, Gemini Ganesan, Heera Raj...
# ...

# %%
# barplot
df_movie['rating'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='rating'>

# %% [markdown]
# ## Normalize text

# %%
# change uppercase/lowercase with atrib str
df_movie['title'].str.title()
df_movie['title'].str.lower()
df_movie['title'].str.upper()
# Out:
# 0                   DICK JOHNSON IS DEAD
# 6       MY LITTLE PONY: A NEW GENERATION
# 7                                SANKOFA
# 9                           THE STARLING
# 12                          JE SUIS KARL
#                       ...
# 8801                             ZINZANA
# 8802                              ZODIAC
# 8804                          ZOMBIELAND
# 8805                                ZOOM
# 8806                              ZUBAAN
# Name: title, Length: 6131, dtype: object

# %%
# apply method
df_movie['title'].apply(lambda x:x.title())
# Out:
# 0                   Dick Johnson Is Dead
# 6       My Little Pony: A New Generation
# 7                                Sankofa
# 9                           The Starling
# 12                          Je Suis Karl
#                       ...
# 8801                             Zinzana
# 8802                              Zodiac
# 8804                          Zombieland
# 8805                                Zoom
# 8806                              Zubaan
# Name: title, Length: 6131, dtype: object

# %% [markdown]
# ## Delete blankspaces

# %%
# strip()
movie_title = ' Titanic   '
print(movie_title)

print(movie_title.strip())
# Out:
#  Titanic
# Titanic

# %%
df_movie['title'].str.strip()
# Out:
# 0                   Dick Johnson Is Dead
# 6       My Little Pony: A New Generation
# 7                                Sankofa
# 9                           The Starling
# 12                          Je Suis Karl
#                       ...
# 8801                             Zinzana
# 8802                              Zodiac
# 8804                          Zombieland
# 8805                                Zoom
# 8806                              Zubaan
# Name: title, Length: 6131, dtype: object

# %%
df_movie['title'].apply(lambda x: x.strip())
# Out:
# 0                   Dick Johnson Is Dead
# 6       My Little Pony: A New Generation
# 7                                Sankofa
# 9                           The Starling
# 12                          Je Suis Karl
#                       ...
# 8801                             Zinzana
# 8802                              Zodiac
# 8804                          Zombieland
# 8805                                Zoom
# 8806                              Zubaan
# Name: title, Length: 6131, dtype: object

# %% [markdown]
# ## Replace text

# %%
# .str.replace() and regex - only strings
df_movie['title'].str.replace('[^\w\s]', '', regex=True)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# /tmp/ipykernel_31164/1412022760.py:2: SyntaxWarning: invalid escape sequence '\w'
#   df_movie['title'].str.replace('[^\w\s]', '', regex=True)
# 0                  Dick Johnson Is Dead
# 6       My Little Pony A New Generation
# 7                               Sankofa
# 9                          The Starling
# 12                         Je Suis Karl
#                      ...
# 8801                            Zinzana
# 8802                             Zodiac
# 8804                         Zombieland
# 8805                               Zoom
# 8806                             Zubaan
# Name: title, Length: 6131, dtype: object

# %%
# delete replace() and regex
df_movie['title'].replace('[^\w\s]', '', regex=True)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# <>:2: SyntaxWarning: invalid escape sequence '\w'
# /tmp/ipykernel_31164/365354361.py:2: SyntaxWarning: invalid escape sequence '\w'
#   df_movie['title'].replace('[^\w\s]', '', regex=True)
# 0                  Dick Johnson Is Dead
# 6       My Little Pony A New Generation
# 7                               Sankofa
# 9                          The Starling
# 12                         Je Suis Karl
#                      ...
# 8801                            Zinzana
# 8802                             Zodiac
# 8804                         Zombieland
# 8805                               Zoom
# 8806                             Zubaan
# Name: title, Length: 6131, dtype: object

# %%
# str - does not work with numbers
df_movie['title'].str.replace(1,2, regex=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[88], line 2
#       1 # replace() and regex
# ----> 2 df_movie['title'].str.replace(1,2, regex=True)
#
# File ~/Workspace/course-data-science/venv/lib/python3.13/site-packages/pandas/core/strings/accessor.py:137, in forbid_nonstring_types.<locals>._forbid_nonstring_types.<locals>.wrapper(self, *args, **kwargs)
#     132     msg = (
#     133         f"Cannot use .str.{func_name} with values of "
#     134         f"inferred dtype '{self._inferred_dtype}'."
#     135     )
#     136     raise TypeError(msg)
# --> 137 return func(self, *args, **kwargs)
#
# File ~/Workspace/course-data-science/venv/lib/python3.13/site-packages/pandas/core/strings/accessor.py:1548, in StringMethods.replace(self, pat, repl, n, case, flags, regex)
#    1546 # Check whether repl is valid (GH 13438, GH 15055)
# ...

# %%
# if it works with numbers
df_movie['title'].replace(1,2, regex=True)
# Out:
# 0                   Dick Johnson Is Dead
# 6       My Little Pony: A New Generation
# 7                                Sankofa
# 9                           The Starling
# 12                          Je Suis Karl
#                       ...
# 8801                             Zinzana
# 8802                              Zodiac
# 8804                          Zombieland
# 8805                                Zoom
# 8806                              Zubaan
# Name: title, Length: 6131, dtype: object

# %%
import re

# delete score with function re.sub()
df_movie['title'].apply(lambda x: re.sub('[^\w\s]', '', x))
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\w'
# <>:4: SyntaxWarning: invalid escape sequence '\w'
# /tmp/ipykernel_31164/734379652.py:4: SyntaxWarning: invalid escape sequence '\w'
#   df_movie['title'].apply(lambda x: re.sub('[^\w\s]', '', x))
# 0                  Dick Johnson Is Dead
# 6       My Little Pony A New Generation
# 7                               Sankofa
# 9                          The Starling
# 12                         Je Suis Karl
#                      ...
# 8801                            Zinzana
# 8802                             Zodiac
# 8804                         Zombieland
# 8805                               Zoom
# 8806                             Zubaan
# Name: title, Length: 6131, dtype: object
