# %% [markdown]
# # JOINS

# %%
import pandas as pd

# %%
df_movies = pd.read_csv('IMDb movies/IMDb movies.csv', low_memory=False)
df_ratings = pd.read_csv('IMDb ratings/IMDb ratings.csv', low_memory=False)

# %%
# select columns
df_movies = df_movies[['imdb_title_id', 'title', 'year', 'genre', 'country']]
df_ratings = df_ratings[['imdb_title_id', 'total_votes', 'mean_vote']]

# %% [markdown]
# ## Inner Join

# %%
df_inner_join = df_movies.merge(df_ratings, on='imdb_title_id', how='inner')
# or pd.merge(df_movies, df_ratings, on='imdb_title_id')

# %%
df_inner_join
# Out:
#       imdb_title_id                           title  year  \
# 0         tt0000009                      Miss Jerry  1894
# 1         tt0000574     The Story of the Kelly Gang  1906
# 2         tt0001892                  Den sorte drøm  1911
# 3         tt0002101                       Cleopatra  1912
# 4         tt0002130                       L'Inferno  1911
# ...             ...                             ...   ...
# 85850     tt9908390                         Le lion  2020
# 85851     tt9911196  De Beentjes van Sint-Hildegard  2020
# 85852     tt9911774       Padmavyuhathile Abhimanyu  2019
# 85853     tt9914286               Sokagin Çocuklari  2019
# 85854     tt9914942      La vida sense la Sara Amat  2019
#
#                            genre           country  total_votes  mean_vote
# 0                        Romance               USA          154        5.9
# 1        Biography, Crime, Drama         Australia          589        6.3
# 2                          Drama  Germany, Denmark          188        6.0
# 3                 Drama, History               USA          446        5.3
# 4      Adventure, Drama, Fantasy             Italy         2237        6.9
# ...                          ...               ...          ...        ...
# 85850                     Comedy   France, Belgium          398        5.5
# 85851              Comedy, Drama       Netherlands          724        7.9
# 85852                      Drama             India          265        7.8
# 85853              Drama, Family            Turkey          194        9.4
# 85854                      Drama             Spain          102        6.8
#
# [85855 rows x 7 columns]

# %%
print(df_inner_join.shape)
print(df_movies.shape)
print(df_ratings.shape)
# Out:
# (85855, 7)
# (85855, 5)
# (85855, 3)

# %% [markdown]
# ## Full joins

# %%
df_full_join = df_movies.merge(df_ratings, on='imdb_title_id', how='outer')

# %%
df_full_join
# Out:
#       imdb_title_id                           title  year  \
# 0         tt0000009                      Miss Jerry  1894
# 1         tt0000574     The Story of the Kelly Gang  1906
# 2         tt0001892                  Den sorte drøm  1911
# 3         tt0002101                       Cleopatra  1912
# 4         tt0002130                       L'Inferno  1911
# ...             ...                             ...   ...
# 85850     tt9908390                         Le lion  2020
# 85851     tt9911196  De Beentjes van Sint-Hildegard  2020
# 85852     tt9911774       Padmavyuhathile Abhimanyu  2019
# 85853     tt9914286               Sokagin Çocuklari  2019
# 85854     tt9914942      La vida sense la Sara Amat  2019
#
#                            genre           country  total_votes  mean_vote
# 0                        Romance               USA          154        5.9
# 1        Biography, Crime, Drama         Australia          589        6.3
# 2                          Drama  Germany, Denmark          188        6.0
# 3                 Drama, History               USA          446        5.3
# 4      Adventure, Drama, Fantasy             Italy         2237        6.9
# ...                          ...               ...          ...        ...
# 85850                     Comedy   France, Belgium          398        5.5
# 85851              Comedy, Drama       Netherlands          724        7.9
# 85852                      Drama             India          265        7.8
# 85853              Drama, Family            Turkey          194        9.4
# 85854                      Drama             Spain          102        6.8
#
# [85855 rows x 7 columns]

# %%
print(df_full_join.shape)
print(df_movies.shape)
print(df_ratings.shape)
# Out:
# (85855, 7)
# (85855, 5)
# (85855, 3)

# %% [markdown]
# ## Exclusive Full Join

# %%
df_exclusive_full_join = df_movies.merge(df_ratings, on='imdb_title_id', how='outer', indicator=True).query('_merge=="left_only" or _merge=="right_only"')

# %%
df_exclusive_full_join
# Out:
# Empty DataFrame
# Columns: [imdb_title_id, title, year, genre, country, total_votes, mean_vote, _merge]
# Index: []

# %% [markdown]
# ## Left Join

# %%
df_sample_movies = df_movies.sample(frac=0.5)

# %%
df_left_join = df_sample_movies.merge(df_ratings, on='imdb_title_id', how='left')

# %%
df_left_join
# Out:
#       imdb_title_id                                title  year  \
# 0         tt8361028                                  Cam  2018
# 1         tt0116325                             Fu sheng  1996
# 2         tt0097695                   Kvinnorna på taket  1989
# 3         tt0156531                                Festa  1989
# 4         tt0045876                        Il trono nero  1954
# ...             ...                                  ...   ...
# 42923     tt0038648         It Shouldn't Happen to a Dog  1946
# 42924     tt4370256  How to Win at Checkers (Every Time)  2015
# 42925     tt0056209             Inferno a Madison Avenue  1961
# 42926     tt3714804                  Suicidio (Hitabdut)  2014
# 42927     tt0073286                      Lezioni private  1975
#
#                               genre                   country  total_votes  \
# 0         Horror, Mystery, Thriller                       USA        24592
# 1                     Comedy, Drama                 Australia          256
# 2                             Drama                    Sweden          143
# 3                     Comedy, Drama                    Brazil          145
# 4      Action, Adventure, Biography                       USA         1130
# ...                             ...                       ...          ...
# 42923     Action, Adventure, Comedy                       USA          144
# 42924                         Drama  Thailand, USA, Indonesia          779
# 42925                         Drama                       USA          285
# 42926       Action, Crime, Thriller                    Israel          318
# 42927                        Comedy                     Italy          261
#
#        mean_vote
# 0            5.8
# 1            7.3
# 2            6.6
# 3            7.1
# 4            6.3
# ...          ...
# 42923        7.0
# 42924        7.3
# 42925        6.0
# 42926        6.4
# 42927        5.6
#
# [42928 rows x 7 columns]

# %%
print(df_left_join.shape)
print(df_sample_movies.shape)
print(df_ratings.shape)
# Out:
# (42928, 7)
# (42928, 5)
# (85855, 3)

# %% [markdown]
# ## Exclusive Left Join

# %%
# copy df
df_copy_movies = df_movies.copy()

# %%
# change values
df_copy_movies.loc[:999, 'imdb_title_id'] = 'tt1234567890'

# %%
df_copy_movies['imdb_title_id']
# Out:
# 0        tt1234567890
# 1        tt1234567890
# 2        tt1234567890
# 3        tt1234567890
# 4        tt1234567890
#              ...
# 85850       tt9908390
# 85851       tt9911196
# 85852       tt9911774
# 85853       tt9914286
# 85854       tt9914942
# Name: imdb_title_id, Length: 85855, dtype: object

# %%
df_exclusive_left_join = df_copy_movies.merge(df_ratings, on='imdb_title_id', how='outer', indicator=True).query('_merge=="left_only"')

# %%
df_exclusive_left_join
# Out:
#       imdb_title_id                        title  year  \
# 55817  tt1234567890                   Miss Jerry  1894
# 55818  tt1234567890  The Story of the Kelly Gang  1906
# 55819  tt1234567890               Den sorte drøm  1911
# 55820  tt1234567890                    Cleopatra  1912
# 55821  tt1234567890                    L'Inferno  1911
# ...             ...                          ...   ...
# 56812  tt1234567890            Agente segreto Z1  1930
# 56813  tt1234567890                   Tom Sawyer  1930
# 56814  tt1234567890               Tonka Sibenice  1930
# 56815  tt1234567890                    Top Speed  1930
# 56816  tt1234567890             True to the Navy  1930
#
#                            genre                  country  total_votes  \
# 55817                    Romance                      USA          NaN
# 55818    Biography, Crime, Drama                Australia          NaN
# 55819                      Drama         Germany, Denmark          NaN
# 55820             Drama, History                      USA          NaN
# 55821  Adventure, Drama, Fantasy                    Italy          NaN
# ...                          ...                      ...          ...
# 56812                      Drama                      USA          NaN
# 56813   Adventure, Comedy, Drama                      USA          NaN
# 56814                      Drama  Czechoslovakia, Germany          NaN
# 56815   Comedy, Musical, Romance                      USA          NaN
# 56816    Action, Comedy, Romance                      USA          NaN
#
#        mean_vote     _merge
# 55817        NaN  left_only
# 55818        NaN  left_only
# 55819        NaN  left_only
# 55820        NaN  left_only
# 55821        NaN  left_only
# ...          ...        ...
# 56812        NaN  left_only
# 56813        NaN  left_only
# 56814        NaN  left_only
# 56815        NaN  left_only
# 56816        NaN  left_only
#
# [1000 rows x 8 columns]
